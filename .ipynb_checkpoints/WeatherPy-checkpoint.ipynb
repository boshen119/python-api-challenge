# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "citypy/worldcities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?q=canillo&APPID=" + api_key
a_city = requests.get(base_url).json()
a_city
# Out:
# {'coord': {'lon': 1.6, 'lat': 42.57},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 274.25,
#   'feels_like': 268.09,
#   'temp_min': 271.48,
#   'temp_max': 277.04,
#   'pressure': 1026,
#   'humidity': 14},
#  'wind': {'speed': 3.52, 'deg': 26},
#  'clouds': {'all': 30},
#  'dt': 1577666997,
#  'sys': {'type': 3,
#   'id': 19636,
#   'country': 'FR',
#   'sunrise': 1577690589,
#   'sunset': 1577723305},
#  'timezone': 3600,
#  'id': 3041204,
#  'name': 'Canillo',
#  'cod': 200}

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?APPID=" + api_key

city_data = []
for i, city in enumerate(cities):
    url = base_url + "&q=" + city
    print("Processing Record %s | %s" %(i,city))
    try:
        city_weather = requests.get(url).json()
        cloudiness=city_weather["clouds"]["all"]
        country=city_weather["sys"]["country"]
        date=city_weather["dt"]
        humidity=city_weather["main"]["humidity"]
        lat=city_weather["coord"]["lat"]
        lng=city_weather["coord"]["lon"]
        max_temp=city_weather["main"]["temp_max"]
        wind_speed=city_weather["wind"]["speed"]
        city_data.append({"City": city,
                         "Cloudiness": cloudiness,
                         "Country" : country,
                         "Date": date,
                         "Humidity": humidity,
                         "Lat": lat,
                         "Lng" : lng,
                         "Max Temp": max_temp,
                         "Wind Speed": wind_speed})
    except:
        print("City not found, skipping")
        pass
# Out:
# Processing Record 0 | butaritari
# Processing Record 1 | fort nelson
# Processing Record 2 | salalah
# Processing Record 3 | dikson
# Processing Record 4 | jamestown
# Processing Record 5 | castro
# Processing Record 6 | saskylakh
# Processing Record 7 | galesong
# Processing Record 8 | ngunguru
# Processing Record 9 | ruteng
# Processing Record 10 | longlac
# City not found, skipping
# Processing Record 11 | tsihombe
# City not found, skipping
# Processing Record 12 | honningsvag
# Processing Record 13 | sinnamary
# Processing Record 14 | bluff
# Processing Record 15 | albany
# Processing Record 16 | sao filipe
# Processing Record 17 | rikitea
# Processing Record 18 | khatanga
# Processing Record 19 | pisco
# Processing Record 20 | acapulco
# Processing Record 21 | hasaki
# Processing Record 22 | new norfolk
# Processing Record 23 | bethel
# Processing Record 24 | lebu
# Processing Record 25 | barstow
# Processing Record 26 | bogande
# Processing Record 27 | ilulissat
# Processing Record 28 | hilo
# Processing Record 29 | altay
# Processing Record 30 | ostrovnoy
# Processing Record 31 | harper
# Processing Record 32 | carnarvon
# Processing Record 33 | hunza
# City not found, skipping
# Processing Record 34 | puerto ayora
# Processing Record 35 | san patricio
# Processing Record 36 | arraial do cabo
# Processing Record 37 | tasiilaq
# Processing Record 38 | yar-sale
# Processing Record 39 | kikerino
# Processing Record 40 | saint-philippe
# Processing Record 41 | nalut
# Processing Record 42 | pichayevo
# Processing Record 43 | port alfred
# Processing Record 44 | eldikan
# City not found, skipping
# Processing Record 45 | contratacion
# Processing Record 46 | balabac
# Processing Record 47 | nikolskoye
# Processing Record 48 | xadani
# City not found, skipping
# Processing Record 49 | kodiak
# Processing Record 50 | the valley
# Processing Record 51 | cherskiy
# Processing Record 52 | esperance
# Processing Record 53 | tripoli
# Processing Record 54 | bredasdorp
# Processing Record 55 | nuevitas
# Processing Record 56 | amderma
# City not found, skipping
# Processing Record 57 | faya
# Processing Record 58 | qaanaaq
# Processing Record 59 | griffith
# Processing Record 60 | noumea
# Processing Record 61 | cape town
# Processing Record 62 | barrow
# Processing Record 63 | okhotsk
# Processing Record 64 | mataura
# Processing Record 65 | constitucion
# Processing Record 66 | sonoita
# Processing Record 67 | bell ville
# Processing Record 68 | iralaya
# Processing Record 69 | sibu
# Processing Record 70 | ushuaia
# Processing Record 71 | dingle
# Processing Record 72 | kamenka
# Processing Record 73 | grand river south east
# City not found, skipping
# Processing Record 74 | atuona
# Processing Record 75 | karratha
# Processing Record 76 | cabo san lucas
# Processing Record 77 | port lincoln
# Processing Record 78 | yellowknife
# Processing Record 79 | busselton
# Processing Record 80 | saint anthony
# Processing Record 81 | murshidabad
# Processing Record 82 | geraldton
# Processing Record 83 | carmen
# Processing Record 84 | ruatoria
# City not found, skipping
# Processing Record 85 | ishigaki
# Processing Record 86 | acuna
# City not found, skipping
# Processing Record 87 | seydi
# Processing Record 88 | yulara
# Processing Record 89 | sistranda
# Processing Record 90 | aden
# Processing Record 91 | at-bashi
# Processing Record 92 | upernavik
# Processing Record 93 | munsingen
# Processing Record 94 | tautira
# Processing Record 95 | prince rupert
# Processing Record 96 | mahebourg
# Processing Record 97 | avarua
# Processing Record 98 | thompson
# Processing Record 99 | riverton
# Processing Record 100 | cidreira
# Processing Record 101 | itarema
# Processing Record 102 | samusu
# City not found, skipping
# Processing Record 103 | haines junction
# Processing Record 104 | barentsburg
# City not found, skipping
# Processing Record 105 | mackenzie
# Processing Record 106 | vardo
# Processing Record 107 | fayetteville
# Processing Record 108 | evensk
# Processing Record 109 | hobart
# Processing Record 110 | victoria
# Processing Record 111 | meulaboh
# Processing Record 112 | bathsheba
# Processing Record 113 | remontnoye
# Processing Record 114 | katangli
# Processing Record 115 | illoqqortoormiut
# City not found, skipping
# Processing Record 116 | cartagena
# Processing Record 117 | matadi
# Processing Record 118 | sao joao da barra
# Processing Record 119 | inuvik
# Processing Record 120 | sola
# Processing Record 121 | asosa
# Processing Record 122 | kysyl-syr
# Processing Record 123 | guerrero negro
# Processing Record 124 | andevoranto
# City not found, skipping
# Processing Record 125 | aneho
# Processing Record 126 | lagoa
# Processing Record 127 | vaitupu
# City not found, skipping
# Processing Record 128 | srednekolymsk
# Processing Record 129 | iqaluit
# Processing Record 130 | kapaa
# Processing Record 131 | namatanai
# Processing Record 132 | parit buntar
# Processing Record 133 | taolanaro
# City not found, skipping
# Processing Record 134 | nam som
# Processing Record 135 | bambous virieux
# Processing Record 136 | niquero
# Processing Record 137 | punta arenas
# Processing Record 138 | avera
# Processing Record 139 | ylivieska
# Processing Record 140 | marsa matruh
# Processing Record 141 | kaitangata
# Processing Record 142 | tura
# Processing Record 143 | burica
# City not found, skipping
# Processing Record 144 | kishtwar
# Processing Record 145 | oriximina
# Processing Record 146 | oyon
# Processing Record 147 | havelock
# Processing Record 148 | kelso
# Processing Record 149 | tuatapere
# Processing Record 150 | grindavik
# Processing Record 151 | zhangye
# Processing Record 152 | east london
# Processing Record 153 | barbar
# City not found, skipping
# Processing Record 154 | sentyabrskiy
# City not found, skipping
# Processing Record 155 | lagos
# Processing Record 156 | imbituba
# Processing Record 157 | codrington
# Processing Record 158 | mount gambier
# Processing Record 159 | villanueva de cordoba
# Processing Record 160 | laguna
# Processing Record 161 | mayo
# Processing Record 162 | portobelo
# Processing Record 163 | salinas
# Processing Record 164 | vaini
# Processing Record 165 | jalu
# Processing Record 166 | dori
# Processing Record 167 | tuktoyaktuk
# Processing Record 168 | sitka
# Processing Record 169 | hithadhoo
# Processing Record 170 | manlleu
# Processing Record 171 | narsaq
# Processing Record 172 | manadhoo
# Processing Record 173 | lompoc
# Processing Record 174 | la ronge
# Processing Record 175 | santana do acarau
# Processing Record 176 | asau
# City not found, skipping
# Processing Record 177 | hermanus
# Processing Record 178 | chuy
# Processing Record 179 | sol-iletsk
# Processing Record 180 | ojinaga
# Processing Record 181 | alofi
# Processing Record 182 | berbera
# City not found, skipping
# Processing Record 183 | methoni
# Processing Record 184 | agva
# City not found, skipping
# Processing Record 185 | severo-kurilsk
# Processing Record 186 | saint george
# Processing Record 187 | praya
# Processing Record 188 | moscow
# Processing Record 189 | taoudenni
# Processing Record 190 | namibe
# Processing Record 191 | longyearbyen
# Processing Record 192 | ihosy
# Processing Record 193 | broken hill
# Processing Record 194 | french harbor
# Processing Record 195 | touros
# Processing Record 196 | port-de-paix
# City not found, skipping
# Processing Record 197 | goure
# Processing Record 198 | turukhansk
# Processing Record 199 | nanortalik
# Processing Record 200 | mrirt
# City not found, skipping
# Processing Record 201 | muslyumovo
# Processing Record 202 | sug-aksy
# City not found, skipping
# Processing Record 203 | opuwo
# Processing Record 204 | alyangula
# Processing Record 205 | gujar khan
# Processing Record 206 | saleaula
# City not found, skipping
# Processing Record 207 | hamilton
# Processing Record 208 | parana
# Processing Record 209 | ulaanbaatar
# Processing Record 210 | ploemeur
# Processing Record 211 | taitung
# Processing Record 212 | ler
# Processing Record 213 | aklavik
# Processing Record 214 | calvinia
# Processing Record 215 | pacific grove
# Processing Record 216 | hihifo
# City not found, skipping
# Processing Record 217 | samarai
# Processing Record 218 | seoul
# Processing Record 219 | ponta do sol
# Processing Record 220 | san quintin
# Processing Record 221 | tual
# Processing Record 222 | quatre cocos
# Processing Record 223 | mutsamudu
# City not found, skipping
# Processing Record 224 | homer
# Processing Record 225 | yinchuan
# Processing Record 226 | chokurdakh
# Processing Record 227 | port elizabeth
# Processing Record 228 | bengkulu
# City not found, skipping
# Processing Record 229 | lima
# Processing Record 230 | nara
# Processing Record 231 | mbacke
# City not found, skipping
# Processing Record 232 | georgetown
# Processing Record 233 | la palma
# Processing Record 234 | cotacachi
# Processing Record 235 | aksarka
# Processing Record 236 | bay roberts
# Processing Record 237 | luderitz
# Processing Record 238 | tortoli
# Processing Record 239 | borba
# Processing Record 240 | pevek
# Processing Record 241 | shetpe
# Processing Record 242 | lipin bor
# Processing Record 243 | rudsar
# Processing Record 244 | lakes entrance
# Processing Record 245 | kentau
# Processing Record 246 | san lazaro
# Processing Record 247 | mae hong son
# Processing Record 248 | songjianghe
# Processing Record 249 | bogotol
# Processing Record 250 | mega
# Processing Record 251 | bronnoysund
# Processing Record 252 | alice springs
# Processing Record 253 | bassano del grappa
# Processing Record 254 | souillac
# Processing Record 255 | hambantota
# Processing Record 256 | sorland
# Processing Record 257 | husavik
# Processing Record 258 | berdigestyakh
# Processing Record 259 | madras
# Processing Record 260 | solnechnyy
# Processing Record 261 | malwan
# City not found, skipping
# Processing Record 262 | honiara
# Processing Record 263 | mys shmidta
# City not found, skipping
# Processing Record 264 | attawapiskat
# City not found, skipping
# Processing Record 265 | necochea
# Processing Record 266 | redmond
# Processing Record 267 | kapuskasing
# Processing Record 268 | naze
# Processing Record 269 | tabuk
# Processing Record 270 | nouadhibou
# Processing Record 271 | marabba
# Processing Record 272 | juybar
# Processing Record 273 | kamen-na-obi
# Processing Record 274 | lerwick
# Processing Record 275 | fortuna
# Processing Record 276 | kurumkan
# Processing Record 277 | luena
# Processing Record 278 | aykhal
# Processing Record 279 | ca mau
# Processing Record 280 | kaeo
# Processing Record 281 | flinders
# Processing Record 282 | moindou
# Processing Record 283 | balikpapan
# Processing Record 284 | murmashi
# Processing Record 285 | rawson
# Processing Record 286 | sorong
# Processing Record 287 | santiago del estero
# Processing Record 288 | moussoro
# Processing Record 289 | mnogovershinnyy
# Processing Record 290 | synya
# Processing Record 291 | bodden town
# Processing Record 292 | garoua
# Processing Record 293 | lukulu
# Processing Record 294 | tomatlan
# Processing Record 295 | ahipara
# Processing Record 296 | vila franca do campo
# Processing Record 297 | salinopolis
# Processing Record 298 | minab
# Processing Record 299 | portland
# Processing Record 300 | ambulu
# Processing Record 301 | kruisfontein
# Processing Record 302 | marawi
# Processing Record 303 | agucadoura
# Processing Record 304 | vezirkopru
# Processing Record 305 | kalmunai
# Processing Record 306 | ucluelet
# Processing Record 307 | svetlaya
# Processing Record 308 | belushya guba
# City not found, skipping
# Processing Record 309 | gueret
# Processing Record 310 | kota kinabalu
# Processing Record 311 | anadyr
# Processing Record 312 | lewiston
# Processing Record 313 | muyezerskiy
# Processing Record 314 | gangotri
# City not found, skipping
# Processing Record 315 | schattdorf
# Processing Record 316 | bonthe
# Processing Record 317 | beringovskiy
# Processing Record 318 | muisne
# Processing Record 319 | toktogul
# Processing Record 320 | bandar-e lengeh
# Processing Record 321 | sabha
# Processing Record 322 | lolua
# City not found, skipping
# Processing Record 323 | zaraza
# Processing Record 324 | cayenne
# Processing Record 325 | bolungarvik
# City not found, skipping
# Processing Record 326 | yantal
# Processing Record 327 | san jeronimo
# Processing Record 328 | gimli
# Processing Record 329 | winton
# Processing Record 330 | barawe
# City not found, skipping
# Processing Record 331 | mar del plata
# Processing Record 332 | grand gaube
# Processing Record 333 | lata
# Processing Record 334 | arlit
# Processing Record 335 | vrangel
# Processing Record 336 | saint-georges
# Processing Record 337 | mandera
# Processing Record 338 | vorozhba
# Processing Record 339 | tananger
# Processing Record 340 | khonuu
# City not found, skipping
# Processing Record 341 | ribeira grande
# Processing Record 342 | nyurba
# Processing Record 343 | mandalgovi
# Processing Record 344 | corozal
# Processing Record 345 | daoukro
# Processing Record 346 | pokosnoye
# Processing Record 347 | vestmannaeyjar
# Processing Record 348 | kolondieba
# Processing Record 349 | otane
# Processing Record 350 | gornyak
# Processing Record 351 | tungor
# Processing Record 352 | rock island
# Processing Record 353 | novobirilyussy
# Processing Record 354 | korla
# City not found, skipping
# Processing Record 355 | guozhen
# Processing Record 356 | port macquarie
# Processing Record 357 | chicama
# Processing Record 358 | isangel
# Processing Record 359 | tuggurt
# City not found, skipping
# Processing Record 360 | kanigiri
# Processing Record 361 | merauke
# Processing Record 362 | kamaishi
# Processing Record 363 | surt
# Processing Record 364 | faanui
# Processing Record 365 | ignacio de la llave
# Processing Record 366 | mao
# Processing Record 367 | sioux lookout
# Processing Record 368 | yumen
# Processing Record 369 | bata
# Processing Record 370 | stromness
# Processing Record 371 | teknaf
# Processing Record 372 | fairbanks
# Processing Record 373 | man
# Processing Record 374 | tabou
# Processing Record 375 | new baltimore
# Processing Record 376 | asyut
# Processing Record 377 | havre-saint-pierre
# Processing Record 378 | erzin
# Processing Record 379 | ambilobe
# Processing Record 380 | shahr-e kord
# Processing Record 381 | komsomolskiy
# Processing Record 382 | morehead
# Processing Record 383 | bandarbeyla
# Processing Record 384 | sorvag
# City not found, skipping
# Processing Record 385 | general roca
# Processing Record 386 | benguela
# Processing Record 387 | stornoway
# City not found, skipping
# Processing Record 388 | shingu
# Processing Record 389 | caohe
# Processing Record 390 | hazorasp
# Processing Record 391 | preobrazheniye
# Processing Record 392 | mayor pablo lagerenza
# Processing Record 393 | mankono
# Processing Record 394 | bama
# Processing Record 395 | ligayan
# Processing Record 396 | norman wells
# Processing Record 397 | gushikawa
# Processing Record 398 | sambava
# Processing Record 399 | nishihara
# Processing Record 400 | bilibino
# Processing Record 401 | zverinogolovskoye
# Processing Record 402 | havoysund
# Processing Record 403 | waipawa
# Processing Record 404 | gambela
# Processing Record 405 | sabang
# Processing Record 406 | coquimbo
# Processing Record 407 | mozarlandia
# Processing Record 408 | halalo
# City not found, skipping
# Processing Record 409 | sur
# Processing Record 410 | kiunga
# Processing Record 411 | teya
# Processing Record 412 | qandala
# Processing Record 413 | nizhneyansk
# City not found, skipping
# Processing Record 414 | hatillo
# Processing Record 415 | kudat
# Processing Record 416 | labuhan
# Processing Record 417 | whitianga
# Processing Record 418 | richards bay
# Processing Record 419 | muri
# Processing Record 420 | makasar
# Processing Record 421 | daru
# Processing Record 422 | oban
# Processing Record 423 | vanimo
# Processing Record 424 | sept-iles
# Processing Record 425 | artyk
# City not found, skipping
# Processing Record 426 | leningradskiy
# Processing Record 427 | bonavista
# Processing Record 428 | gwanda
# Processing Record 429 | deputatskiy
# Processing Record 430 | pajapita
# Processing Record 431 | shenzhen
# Processing Record 432 | mantua
# Processing Record 433 | dingzhou
# Processing Record 434 | tolmezzo
# Processing Record 435 | hofgeismar
# Processing Record 436 | nabire
# Processing Record 437 | lorengau
# Processing Record 438 | labutta
# City not found, skipping
# Processing Record 439 | saint-pierre
# Processing Record 440 | cockburn harbour
# City not found, skipping
# Processing Record 441 | zhezkazgan
# Processing Record 442 | naberera
# Processing Record 443 | biankouma
# Processing Record 444 | kupang
# Processing Record 445 | marcona
# City not found, skipping
# Processing Record 446 | pochutla
# Processing Record 447 | sicamous
# Processing Record 448 | krasnohrad
# Processing Record 449 | jieshi
# Processing Record 450 | tilichiki
# Processing Record 451 | naples
# Processing Record 452 | vostok
# Processing Record 453 | airai
# Processing Record 454 | panguipulli
# Processing Record 455 | tuy hoa
# Processing Record 456 | umm lajj
# Processing Record 457 | houma
# Processing Record 458 | thinadhoo
# Processing Record 459 | makakilo city
# Processing Record 460 | bambanglipuro
# Processing Record 461 | rexburg
# Processing Record 462 | mala
# Processing Record 463 | zaoyang
# Processing Record 464 | morondava
# Processing Record 465 | forestville
# Processing Record 466 | pangody
# Processing Record 467 | talnakh
# Processing Record 468 | yazd
# Processing Record 469 | port blair
# Processing Record 470 | vila
# Processing Record 471 | te anau
# Processing Record 472 | kingston
# Processing Record 473 | trat
# Processing Record 474 | ngukurr
# City not found, skipping
# Processing Record 475 | pauini
# Processing Record 476 | ayan
# Processing Record 477 | eyl
# Processing Record 478 | rocha
# Processing Record 479 | hobyo
# Processing Record 480 | gao
# Processing Record 481 | palmer
# Processing Record 482 | tumannyy
# City not found, skipping
# Processing Record 483 | mentok
# City not found, skipping
# Processing Record 484 | tessaoua
# Processing Record 485 | yeniseysk
# Processing Record 486 | asha
# Processing Record 487 | lubyany
# Processing Record 488 | henties bay
# Processing Record 489 | lishan
# Processing Record 490 | ugoofaaru
# Processing Record 491 | dolores
# Processing Record 492 | coihaique
# Processing Record 493 | poya
# Processing Record 494 | arroyo
# Processing Record 495 | vanavara
# Processing Record 496 | bogolyubovo
# City not found, skipping
# Processing Record 497 | buraydah
# Processing Record 498 | grenaa
# Processing Record 499 | mehamn
# Processing Record 500 | taltal
# Processing Record 501 | rio grande
# Processing Record 502 | bayanday
# Processing Record 503 | achisay
# City not found, skipping
# Processing Record 504 | batangafo
# Processing Record 505 | trincomalee
# Processing Record 506 | puteyets
# Processing Record 507 | bafq
# Processing Record 508 | praia da vitoria
# Processing Record 509 | manicore
# Processing Record 510 | diego de almagro
# Processing Record 511 | kununurra
# Processing Record 512 | banda aceh
# Processing Record 513 | charlestown
# Processing Record 514 | porto novo
# Processing Record 515 | siderno
# Processing Record 516 | ankang
# Processing Record 517 | mutata
# Processing Record 518 | guiratinga
# Processing Record 519 | atotonilco el alto
# Processing Record 520 | oktyabrskiy
# Processing Record 521 | goderich
# Processing Record 522 | hami
# Processing Record 523 | dolbeau
# City not found, skipping
# Processing Record 524 | watsa
# Processing Record 525 | kilindoni
# Processing Record 526 | kokoda
# Processing Record 527 | palabuhanratu
# City not found, skipping
# Processing Record 528 | san luis
# Processing Record 529 | pontianak
# Processing Record 530 | roma
# Processing Record 531 | beidao
# Processing Record 532 | banjar
# Processing Record 533 | san cristobal
# Processing Record 534 | van
# Processing Record 535 | lavrentiya
# Processing Record 536 | bauchi
# Processing Record 537 | saldanha
# Processing Record 538 | gat
# Processing Record 539 | college
# Processing Record 540 | margate
# Processing Record 541 | elban
# Processing Record 542 | vao
# Processing Record 543 | babenhausen
# Processing Record 544 | colares
# Processing Record 545 | churapcha
# Processing Record 546 | sao luis de montes belos
# Processing Record 547 | berlevag
# Processing Record 548 | kemijarvi
# City not found, skipping
# Processing Record 549 | zemio
# Processing Record 550 | galle
# Processing Record 551 | ormara
# Processing Record 552 | alugan
# Processing Record 553 | batemans bay
# Processing Record 554 | kargil
# Processing Record 555 | sevierville
# Processing Record 556 | harrison
# Processing Record 557 | jeffersontown
# Processing Record 558 | kavieng
# Processing Record 559 | puerto del rosario
# Processing Record 560 | alekseyevsk
# Processing Record 561 | abrau-dyurso
# Processing Record 562 | whithorn
# Processing Record 563 | puerto escondido
# Processing Record 564 | ondorhaan
# City not found, skipping
# Processing Record 565 | santa isabel
# Processing Record 566 | amuntai
# Processing Record 567 | hvolsvollur
# City not found, skipping
# Processing Record 568 | los llanos de aridane
# Processing Record 569 | palembang
# Processing Record 570 | saint-augustin
# Processing Record 571 | terrace
# Processing Record 572 | dom pedrito
# Processing Record 573 | mount isa
# Processing Record 574 | siverek
# Processing Record 575 | skibbereen
# Processing Record 576 | arman
# Processing Record 577 | nuevo laredo
# Processing Record 578 | victor harbor
# Processing Record 579 | ushtobe
# Processing Record 580 | paamiut
# Processing Record 581 | abancay
# Processing Record 582 | lakatoro
# Processing Record 583 | peto
# Processing Record 584 | kloulklubed
# Processing Record 585 | susanville
# Processing Record 586 | mattru
# Processing Record 587 | riachao das neves
# Processing Record 588 | mezen
# Processing Record 589 | tocopilla
# Processing Record 590 | olinda
# Processing Record 591 | zonguldak
# Processing Record 592 | tubruq
# City not found, skipping
# Processing Record 593 | elbistan
# Processing Record 594 | torbay
# Processing Record 595 | ukiah
# Processing Record 596 | asmara
# Processing Record 597 | voskresenskoye
# Processing Record 598 | barcelos
# Processing Record 599 | albertville
# Processing Record 600 | baiyin
# Processing Record 601 | iquitos
# Processing Record 602 | gupitan
# Processing Record 603 | am timan
# Processing Record 604 | abu samrah
# Processing Record 605 | muros
# Processing Record 606 | ambodifototra
# City not found, skipping
# Processing Record 607 | anacortes
# Processing Record 608 | kropotkin
# Processing Record 609 | pangnirtung
# Processing Record 610 | ellensburg
# Processing Record 611 | kalabo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(city_data)
city_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   butaritari          97      KI  1577668184        75   3.07  172.79
# 1  fort nelson          90      CA  1577668184        76  58.81 -122.69
# 2      salalah          39      OM  1577668184        69  17.01   54.10
# 3       dikson         100      RU  1577668185        94  73.51   80.55
# 4    jamestown          42      AU  1577668176        18 -33.21  138.60
#
#    Max Temp  Wind Speed
# 0    301.94        5.61
# 1    253.15        1.00
# 2    298.15        4.10
# 3    254.16       13.59
# 4    309.13        9.52

# %%
city_df.to_csv("City_Weather_Output.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
